# %%
import pandas as pd
import numpy  as np
df = pd.DataFrame([\
                   ['frank', 'M',    np.nan], \
                   ['mary' , np.nan, np.nan], \
                   ['tom'  , 'M',    35], \
                   ['ted'  , 'M',    33], \
                   ['jean' , np.nan, 21], \
                   ['lisa' , 'F',    20]])
df.columns = ['name', 'gender', 'age']
df
# Out:
#     name gender   age
# 0  frank      M   NaN
# 1   mary    NaN   NaN
# 2    tom      M  35.0
# 3    ted      M  33.0
# 4   jean    NaN  21.0
# 5   lisa      F  20.0

# %%
df['gender'].notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# Name: gender, dtype: bool

# %%
df['age'].isnull().values.any()
# Out:
# True

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['age'].isnull().sum()
# Out:
# 2

# %%
df.isnull().sum().sum()
# Out:
# 4
